# %%
import numpy as np
import matplotlib.pyplot as plt
from sys import stdin, stdout

# %%
d = np.genfromtxt('fqsp_tsne.tsv', delimiter='\t')
d -= d.min(axis=0)
d /= d.max(axis=0)

# %%
plt.figure(figsize=(20,10))
plt.scatter(d[:, 0], d[:, 1])
plt.show()
